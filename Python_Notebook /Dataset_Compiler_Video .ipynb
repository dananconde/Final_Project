# %%
# Dependencies

import pandas as pd
import numpy as np
import os

# %%
# Reading in datasets

reviews = pd.read_json("Resources/reviews_Amazon_Instant_Video_5.json", lines=True)
reviews.head()
# Out:
#          asin helpful  overall  \
# 0  B000H00VBQ  [0, 0]        2
# 1  B000H00VBQ  [0, 0]        5
# 2  B000H00VBQ  [0, 1]        1
# 3  B000H00VBQ  [0, 0]        4
# 4  B000H00VBQ  [1, 1]        5
#
#                                           reviewText   reviewTime  \
# 0  I had big expectations because I love English ...   05 3, 2014
# 1  I highly recommend this series. It is a must f...   09 3, 2012
# 2  This one is a real snoozer. Don't believe anyt...  10 16, 2013
# 3  Mysteries are interesting.  The tension betwee...  10 30, 2013
# 4  This show always is excellent, as far as briti...  02 11, 2009
#
#        reviewerID                    reviewerName  \
# 0  A11N155CW1UV02                        AdrianaM
# 1  A3BC8O2KCL29V2                         Carol T
# 2   A60D5HQFOTSOM  Daniel Cooper "dancoopermedia"
# 3  A1RJPIGRSNX4PW                  J. Kaplan "JJ"
# 4  A16XRPF40679KG                   Michael Dobey
#
#                           summary  unixReviewTime
# 0      A little bit boring for me      1399075200
# 1           Excellent Grown Up TV      1346630400
# 2           Way too boring for me      1381881600
# 3     Robson Green is mesmerizing      1383091200
# 4  Robson green and great writing      1234310400

# %%
# Filtering Columns

new_reviews = reviews[["asin", "overall", "reviewText", "summary"]]
new_reviews.columns = ["ASIN", "Star_Rating", "Review", "Summary"]
new_reviews.describe()
# Out:
#        Star_Rating
# count  37126.00000
# mean       4.20953
# std        1.11855
# min        1.00000
# 25%        4.00000
# 50%        5.00000
# 75%        5.00000
# max        5.00000

# %%
def strip_punc_py(words):
  return "".join(char if (char.isalpha() or char == " ") else "" for char in words)

new_reviews["Clean_Review"] = new_reviews["Review"].map(strip_punc_py)

new_reviews.head(20)
# Out:
# /Users/danielconde/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#           ASIN  Star_Rating  \
# 0   B000H00VBQ            2
# 1   B000H00VBQ            5
# 2   B000H00VBQ            1
# 3   B000H00VBQ            4
# 4   B000H00VBQ            5
# 5   B000H00VBQ            5
# 6   B000H0X79O            3
# 7   B000H0X79O            3
# 8   B000H0X79O            5
# 9   B000H0X79O            3
# 10  B000H0X79O            4
# 11  B000H29TXU            4
# 12  B000H29TXU            3
# 13  B000H29TXU            3
# 14  B000H29TXU            5
# 15  B000H29TXU            2
# 16  B000H2DMME            3
# 17  B000H2DMME            3
# 18  B000H2DMME            5
# 19  B000H2DMME            5
#
#                                                Review  \
# 0   I had big expectations because I love English ...
# 1   I highly recommend this series. It is a must f...
# 2   This one is a real snoozer. Don't believe anyt...
# 3   Mysteries are interesting.  The tension betwee...
# 4   This show always is excellent, as far as briti...
# 5   I discovered this series quite by accident. Ha...
# 6   It beats watching a blank screen. However, I j...
# 7   There are many episodes in this series, so I p...
# 8   This is the best of the best comedy Stand-up. ...
# 9   Not bad.  Didn't know any of the comedians but...
# 10  Funny, interesting, a great way to pass time. ...
# 11  I love the variety of comics.  Great for dinne...
# 12  comedy is a matter of taste. this guy was a li...
# 13  if this had to do with Dat Phan, he was hilari...
# 14  Watched it for Kevin Hart and only Kevin Hart!...
# 15  he's OK. His humor consists mainly of varying ...
# 16  some comedians are very good, some not so good...
# 17  I only watched the Wanda Sykes portion of this...
# 18  Enjoyed some of the comedians, it was a joy to...
# 19  All the comedians are hilarious. I have seen t...
#
#                                               Summary  \
# 0                          A little bit boring for me
# 1                               Excellent Grown Up TV
# 2                               Way too boring for me
# 3                         Robson Green is mesmerizing
# 4                      Robson green and great writing
# 5   I purchased the series via streaming and loved...
# 6                              It takes up your time.
# 7              A reasonable way to kill a few minutes
# 8                                           kansas001
# 9                                 Entertaining Comedy
# 10                                    Worth watching!
# 11      comedy club quality without leaving your home
# 12                                                 ok
# 13                          not sure who this was for
# 14                                          Loved it!
# 15         same routine he did on last comic standing
# 16                                          it was ok
# 17                         I Only Watched Wanda Sykes
# 18                                    Some were funny
# 19                                             kansas
#
#                                          Clean_Review
# 0   I had big expectations because I love English ...
# 1   I highly recommend this series It is a must fo...
# 2   This one is a real snoozer Dont believe anythi...
# 3   Mysteries are interesting  The tension between...
# 4   This show always is excellent as far as britis...
# 5   I discovered this series quite by accident Hav...
# 6   It beats watching a blank screen However I jus...
# 7   There are many episodes in this series so I pr...
# 8   This is the best of the best comedy Standup Th...
# 9   Not bad  Didnt know any of the comedians but f...
# 10  Funny interesting a great way to pass time I u...
# 11  I love the variety of comics  Great for dinner...
# 12  comedy is a matter of taste this guy was a lit...
# 13  if this had to do with Dat Phan he was hilario...
# 14  Watched it for Kevin Hart and only Kevin Hart ...
# 15  hes OK His humor consists mainly of varying be...
# 16  some comedians are very good some not so good ...
# 17  I only watched the Wanda Sykes portion of this...
# 18  Enjoyed some of the comedians it was a joy to ...
# 19  All the comedians are hilarious I have seen th...

# %%
# Drop empty cells in 'Review' column
clean_reviews = new_reviews[["ASIN", "Star_Rating", "Summary", "Clean_Review"]]
clean_reviews = clean_reviews.dropna(subset=["Clean_Review"])
clean_reviews.Star_Rating = clean_reviews.Star_Rating.astype(int)
clean_reviews.head(20)
# Out:
#           ASIN  Star_Rating  \
# 0   B000H00VBQ            2
# 1   B000H00VBQ            5
# 2   B000H00VBQ            1
# 3   B000H00VBQ            4
# 4   B000H00VBQ            5
# 5   B000H00VBQ            5
# 6   B000H0X79O            3
# 7   B000H0X79O            3
# 8   B000H0X79O            5
# 9   B000H0X79O            3
# 10  B000H0X79O            4
# 11  B000H29TXU            4
# 12  B000H29TXU            3
# 13  B000H29TXU            3
# 14  B000H29TXU            5
# 15  B000H29TXU            2
# 16  B000H2DMME            3
# 17  B000H2DMME            3
# 18  B000H2DMME            5
# 19  B000H2DMME            5
#
#                                               Summary  \
# 0                          A little bit boring for me
# 1                               Excellent Grown Up TV
# 2                               Way too boring for me
# 3                         Robson Green is mesmerizing
# 4                      Robson green and great writing
# 5   I purchased the series via streaming and loved...
# 6                              It takes up your time.
# 7              A reasonable way to kill a few minutes
# 8                                           kansas001
# 9                                 Entertaining Comedy
# 10                                    Worth watching!
# 11      comedy club quality without leaving your home
# 12                                                 ok
# 13                          not sure who this was for
# 14                                          Loved it!
# 15         same routine he did on last comic standing
# 16                                          it was ok
# 17                         I Only Watched Wanda Sykes
# 18                                    Some were funny
# 19                                             kansas
#
#                                          Clean_Review
# 0   I had big expectations because I love English ...
# 1   I highly recommend this series It is a must fo...
# 2   This one is a real snoozer Dont believe anythi...
# 3   Mysteries are interesting  The tension between...
# 4   This show always is excellent as far as britis...
# 5   I discovered this series quite by accident Hav...
# 6   It beats watching a blank screen However I jus...
# 7   There are many episodes in this series so I pr...
# 8   This is the best of the best comedy Standup Th...
# 9   Not bad  Didnt know any of the comedians but f...
# 10  Funny interesting a great way to pass time I u...
# 11  I love the variety of comics  Great for dinner...
# 12  comedy is a matter of taste this guy was a lit...
# 13  if this had to do with Dat Phan he was hilario...
# 14  Watched it for Kevin Hart and only Kevin Hart ...
# 15  hes OK His humor consists mainly of varying be...
# 16  some comedians are very good some not so good ...
# 17  I only watched the Wanda Sykes portion of this...
# 18  Enjoyed some of the comedians it was a joy to ...
# 19  All the comedians are hilarious I have seen th...

# %%
# Exporting final training data as csv

clean_reviews.to_csv("amazon_video_training.csv", index=False)

# %%
clean_reviews.head()
# Out:
#          ASIN  Star_Rating                         Summary  \
# 0  B000H00VBQ            2      A little bit boring for me
# 1  B000H00VBQ            5           Excellent Grown Up TV
# 2  B000H00VBQ            1           Way too boring for me
# 3  B000H00VBQ            4     Robson Green is mesmerizing
# 4  B000H00VBQ            5  Robson green and great writing
#
#                                         Clean_Review
# 0  I had big expectations because I love English ...
# 1  I highly recommend this series It is a must fo...
# 2  This one is a real snoozer Dont believe anythi...
# 3  Mysteries are interesting  The tension between...
# 4  This show always is excellent as far as britis...
